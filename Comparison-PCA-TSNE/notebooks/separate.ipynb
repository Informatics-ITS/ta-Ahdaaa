# %% [markdown]
# ##### Analyse Cleaned Datasets

# %%
import sys
sys.path.append("..")  # go back one folder

from main import run_summary

df = run_summary()
# Out:
# Dataset  Jumlah Atribut  Jumlah Instance  Jumlah Defective  Jumlah Tidak Defective Nama File
#     CM1              37              327                42                     285  CM1.arff
#     JM1              21             7720              1612                    6108  JM1.arff
#     KC1              21             1162               294                     868  KC1.arff
#     KC3              39              194                36                     158  KC3.arff
#     KC4               0                0                 0                       0  KC4.arff
#     MC1              38             1952                36                    1916  MC1.arff
#     MC2              39              124                44                      80  MC2.arff
#     MW1              37              250                25                     225  MW1.arff
#     PC1              37              679                55                     624  PC1.arff
#     PC2              36              722                16                     706  PC2.arff
#     PC3              37             1053               130                     923  PC3.arff
#     PC4              37             1270               176                    1094  PC4.arff
#     PC5              38             1694               458                    1236  PC5.arff

# %% [markdown]
# ##### Load Single Dataset

# %%
from main import load_single

dataset_name = "PC5"
lowercase_dataset = dataset_name.lower()

merged = load_single(f"{dataset_name}.arff")
merged.head()
# Out:
# (1694, 39)
#    loc_blank  branch_count  call_pairs  loc_code_and_comment  loc_comments  \
# 0       49.0          77.0         6.0                   6.0          72.0
# 1       15.0           9.0         2.0                   2.0          41.0
# 2        9.0          49.0         6.0                   9.0          52.0
# 3        1.0           1.0         0.0                   0.0           0.0
# 4        3.0           7.0         3.0                   1.0           2.0
#
#    condition_count  cyclomatic_complexity  cyclomatic_density  decision_count  \
# 0            118.0                   39.0                0.19            42.0
# 1             24.0                    5.0                0.25             8.0
# 2             76.0                   25.0                0.36            28.0
# 3              8.0                    1.0                0.50             2.0
# 4             10.0                    4.0                0.29             4.0
#
#    design_complexity  ...  node_count  normalized_cylomatic_complexity  \
# 0                7.0  ...       103.0                             0.12
# 1                1.0  ...        16.0                             0.06
# 2               13.0  ...        77.0                             0.19
# 3                1.0  ...         2.0                             0.20
# 4                2.0  ...        12.0                             0.19
#
#    num_operands  num_operators  num_unique_operands  num_unique_operators  \
# 0         267.0          527.0                 43.0                  20.0
# 1          38.0           78.0                 19.0                  12.0
# 2         146.0          184.0                 16.0                  20.0
# 3           6.0           12.0                  4.0                   6.0
# 4          18.0           23.0                  9.0                  12.0
#
#    number_of_lines  percent_comments  loc_total  defective
# 0            329.0             28.06      206.0          1
# 1             78.0             70.49       20.0          0
# 2            133.0             50.00       70.0          0
# 3              5.0              0.00        2.0          0
# 4             21.0             18.75       14.0          0
#
# [5 rows x 39 columns]

# %% [markdown]
# ##### Exploratory Data Analysis (EDA)

# %% [markdown]
# Number of Instance dan Label Distribution

# %%
print("Jumlah total instance:", len(merged))
print("\nDistribusi label 'defective':")
print(merged['defective'].value_counts())
print("\nProporsi:")
print(merged['defective'].value_counts(normalize=True))
# Out:
# Jumlah total instance: 722
#
# Distribusi label 'defective':
# defective
# 0    706
# 1     16
# Name: count, dtype: int64
#
# Proporsi:
# defective
# 0    0.977839
# 1    0.022161
# Name: proportion, dtype: float64

# %% [markdown]
# Describe Feature Statistic

# %%
merged.describe()
# Out:
#        branch_count  call_pairs  loc_code_and_comment  loc_comments  \
# count    722.000000  722.000000            722.000000    722.000000
# mean       7.632964    3.745152             14.572022      5.746537
# std       13.709677    5.565785             29.980270     13.723372
# min        1.000000    0.000000              0.000000      0.000000
# 25%        3.000000    1.000000              4.000000      0.000000
# 50%        5.000000    2.000000              8.000000      0.000000
# 75%        7.750000    4.000000             15.000000      4.000000
# max      287.000000   74.000000            558.000000    111.000000
#
#        condition_count  cyclomatic_complexity  cyclomatic_density  \
# count       722.000000             722.000000          722.000000
# mean         12.091413               4.396122            0.383781
# std          25.624569               7.035546            0.221362
# min           4.000000               1.000000            0.030000
# 25%           4.000000               2.000000            0.230000
# 50%           8.000000               3.000000            0.330000
# 75%          12.000000               5.000000            0.500000
# max         570.000000             144.000000            1.000000
#
#        decision_count  decision_density  design_complexity  ...  node_count  \
# count      722.000000        722.000000         722.000000  ...  722.000000
# mean         5.675900          2.135125           3.184211  ...   16.767313
# std         12.420296          0.362205           5.726850  ...   28.266439
# min          2.000000          2.000000           1.000000  ...    2.000000
# 25%          2.000000          2.000000           2.000000  ...    7.000000
# 50%          4.000000          2.000000           2.000000  ...   10.500000
# 75%          6.000000          2.000000           3.000000  ...   18.000000
# max        284.000000          7.000000         115.000000  ...  568.000000
#
#        normalized_cylomatic_complexity  num_operands  num_operators  \
# count                       722.000000    722.000000     722.000000
# mean                          0.239612     32.494460      47.073407
# std                           0.119617     58.652134      85.665228
# min                           0.020000      1.000000       4.000000
# 25%                           0.150000      9.000000      13.250000
# 50%                           0.220000     17.000000      25.000000
# 75%                           0.310000     32.000000      45.000000
# max                           0.600000    843.000000    1198.000000
#
#        num_unique_operands  num_unique_operators  number_of_lines  \
# count           722.000000            722.000000       722.000000
# mean             12.718837             11.896122        25.659280
# std              17.965058              4.962440        43.816098
# min               1.000000              4.000000         4.000000
# 25%               5.250000              8.000000         9.000000
# 50%               9.000000             11.000000        15.000000
# 75%              14.000000             14.000000        26.000000
# max             245.000000             46.000000       776.000000
#
#        percent_comments   loc_total   defective
# count        722.000000  722.000000  722.000000
# mean          81.051620   17.198061    0.022161
# std           11.422686   34.259406    0.147308
# min            0.000000    2.000000    0.000000
# 25%           75.000000    5.000000    0.000000
# 50%           83.330000   10.000000    0.000000
# 75%           88.890000   18.000000    0.000000
# max           98.250000  663.000000    1.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# Feature Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 12))
sns.heatmap(merged.drop(columns=["defective"]).corr(), cmap="coolwarm", annot=False)
plt.title("Korelasi antar Fitur")
plt.show()

# %% [markdown]
# Feature Correlation to Defective Label

# %%
label_corr = merged.corr()["defective"].drop("defective").sort_values(ascending=False)
label_corr.plot(kind="barh", figsize=(10, 8), title="Korelasi Fitur terhadap Label Defective")
plt.xlabel("Nilai Korelasi")
plt.show()

# %% [markdown]
# ##### Oversampling

# %% [markdown]
# Imports

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Separate Feature and Defective Label

# %%
X = merged.drop(columns=["defective"])
y = merged["defective"]

# %% [markdown]
# Oversampling with SMOTE

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
print("Sebelum Oversampling:")
print(y.value_counts())

print("\nSetelah Oversampling:")
print(pd.Series(y_resampled).value_counts())
# Out:
# Sebelum Oversampling:
# defective
# 0    1236
# 1     458
# Name: count, dtype: int64
#
# Setelah Oversampling:
# defective
# 1    1236
# 0    1236
# Name: count, dtype: int64

# %% [markdown]
# Visualization

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.countplot(x=y, ax=ax[0])
ax[0].set_title("Distribusi Label Sebelum Oversampling")

sns.countplot(x=y_resampled, ax=ax[1])
ax[1].set_title("Distribusi Label Setelah Oversampling")

plt.tight_layout()
plt.show()

# %% [markdown]
# Store the Results

# %%
df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled["defective"] = y_resampled

# %% [markdown]
# ##### Normalization

# %% [markdown]
# Normalization with Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_resampled.drop(columns=['defective']))

# Simpan label
y_scaled = df_resampled['defective']

# %%
# Konversi kembali ke DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=df_resampled.drop(columns=['defective']).columns)

# Tampilkan beberapa baris pertama
X_scaled_df.head()
# Out:
#    loc_blank  branch_count  call_pairs  loc_code_and_comment  loc_comments  \
# 0   0.821728      1.245690    0.308157              0.147706      0.950384
# 1  -0.001451     -0.261522   -0.369328             -0.234409      0.386421
# 2  -0.146718      0.625073    0.308157              0.434292      0.586537
# 3  -0.340407     -0.438841   -0.708070             -0.425466     -0.359465
# 4  -0.291985     -0.305852   -0.199957             -0.329937     -0.323080
#
#    condition_count  cyclomatic_complexity  cyclomatic_density  decision_count  \
# 0         1.177471               1.201218           -0.189226        0.967362
# 1        -0.112220              -0.268978            0.208248       -0.179845
# 2         0.601226               0.595843            0.936951        0.494983
# 3        -0.331742              -0.441942            1.864390       -0.382294
# 4        -0.304302              -0.312219            0.473231       -0.314811
#
#    design_complexity  ...  multiple_condition_count  node_count  \
# 0           0.154155  ...                  1.202187    0.698909
# 1          -0.452462  ...                 -0.121662   -0.301949
# 2           0.760771  ...                  0.527774    0.399802
# 3          -0.452462  ...                 -0.321488   -0.463007
# 4          -0.351360  ...                 -0.296510   -0.347966
#
#    normalized_cylomatic_complexity  num_operands  num_operators  \
# 0                        -0.198457      0.265914       0.418855
# 1                        -0.865136     -0.281299      -0.238162
# 2                         0.579335     -0.023225      -0.083053
# 3                         0.690449     -0.357766      -0.334739
# 4                         0.579335     -0.329091      -0.318643
#
#    num_unique_operands  num_unique_operators  number_of_lines  \
# 0             0.128014              0.778249         0.680712
# 1            -0.195517             -0.147556        -0.169402
# 2            -0.235958              0.778249         0.016878
# 3            -0.397724             -0.841910        -0.416646
# 4            -0.330321             -0.147556        -0.362456
#
#    percent_comments  loc_total
# 0          0.499867   0.547420
# 1          3.077872  -0.329735
# 2          1.832920  -0.093941
# 3         -1.205031  -0.414621
# 4         -0.065800  -0.358030
#
# [5 rows x 38 columns]

# %% [markdown]
# ##### Without Dimension Reduction -> Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# 1️⃣ Split langsung dari X_scaled (tanpa PCA)
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
)

# 2️⃣ Inisialisasi model (sama seperti sebelumnya)
models = {
    "Logistic Regression": LogisticRegression(solver='saga', max_iter=1000, random_state=42),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", random_state=42)
}

# 3️⃣ Evaluasi model
results = []

for name, model in models.items():
    model.fit(X_train_raw, y_train)  # ← langsung pakai X_train_raw
    y_pred = model.predict(X_test_raw)  # ← langsung pakai X_test_raw

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1-Score": f1_score(y_test, y_pred)
    })

    print(f"\n==== {name} ====")
    print(classification_report(y_test, y_pred))

# 4️⃣ Simpan hasil ke DataFrame
import pandas as pd
df_results = pd.DataFrame(results)
print("\n✅ Hasil evaluasi tanpa reduksi dimensi:")
print(df_results)
# Out:
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression ====
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       248
#            1       0.68      0.66      0.67       247
#
#     accuracy                           0.67       495
#    macro avg       0.67      0.67      0.67       495
# weighted avg       0.67      0.67      0.67       495
#
#
# ==== SVM ====
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       248
#            1       0.71      0.74      0.73       247
#
#     accuracy                           0.72       495
#    macro avg       0.72      0.72      0.72       495
# weighted avg       0.72      0.72      0.72       495
#
#
# ==== KNN ====
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77       248
#            1       0.75      0.86      0.80       247
#
#     accuracy                           0.78       495
#    macro avg       0.79      0.78      0.78       495
# weighted avg       0.79      0.78      0.78       495
#
#
# ==== Random Forest ====
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       248
#            1       0.83      0.87      0.85       247
#
#     accuracy                           0.84       495
#    macro avg       0.85      0.84      0.84       495
# weighted avg       0.85      0.84      0.84       495
#
#
# ==== AdaBoost ====
#               precision    recall  f1-score   support
#
#            0       0.70      0.68      0.69       248
#            1       0.69      0.71      0.70       247
#
#     accuracy                           0.70       495
#    macro avg       0.70      0.70      0.70       495
# weighted avg       0.70      0.70      0.70       495
#
#
# ==== Gradient Boosting ====
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80       248
#            1       0.81      0.78      0.80       247
#
#     accuracy                           0.80       495
#    macro avg       0.80      0.80      0.80       495
# weighted avg       0.80      0.80      0.80       495
#
#
# ==== CatBoost ====
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       248
#            1       0.84      0.86      0.85       247
#
#     accuracy                           0.85       495
#    macro avg       0.85      0.85      0.85       495
# weighted avg       0.85      0.85      0.85       495
#
#
# ==== XGBoost ====
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       248
#            1       0.84      0.86      0.85       247
#
#     accuracy                           0.85       495
#    macro avg       0.85      0.85      0.85       495
# weighted avg       0.85      0.85      0.85       495
#
#
# ✅ Hasil evaluasi tanpa reduksi dimensi:
#                  Model  Accuracy  Precision    Recall  F1-Score
# 0  Logistic Regression  0.672727   0.677824  0.655870  0.666667
# 1                  SVM  0.719192   0.707692  0.744939  0.725838
# 2                  KNN  0.783838   0.746479  0.858300  0.798493
# 3        Random Forest  0.844444   0.829457  0.866397  0.847525
# 4             AdaBoost  0.696970   0.690196  0.712551  0.701195
# 5    Gradient Boosting  0.800000   0.810924  0.781377  0.795876
# 6             CatBoost  0.850505   0.844622  0.858300  0.851406
# 7              XGBoost  0.848485   0.841270  0.858300  0.849699

# %%
# Tampilkan dalam bentuk DataFrame
df_results = pd.DataFrame(results)

# Urutkan berdasarkan F1-Score tertinggi
df_results_sorted = df_results.sort_values(by="F1-Score", ascending=False)

# Tampilkan hasil akhir
print("\n✅ Hasil Evaluasi Model Tanpa PCA dan t-SNE:")
print(df_results_sorted.to_string(index=False))

df_results_sorted.to_clipboard(index=False, excel=True, sep='\t')
# Out:
# ✅ Hasil Evaluasi Model Tanpa PCA dan t-SNE:
#               Model  Accuracy  Precision   Recall  F1-Score
#            CatBoost  0.850505   0.844622 0.858300  0.851406
#             XGBoost  0.848485   0.841270 0.858300  0.849699
#       Random Forest  0.844444   0.829457 0.866397  0.847525
#                 KNN  0.783838   0.746479 0.858300  0.798493
#   Gradient Boosting  0.800000   0.810924 0.781377  0.795876
#                 SVM  0.719192   0.707692 0.744939  0.725838
#            AdaBoost  0.696970   0.690196 0.712551  0.701195
# Logistic Regression  0.672727   0.677824 0.655870  0.666667

# %% [markdown]
# ##### PCA

# %% [markdown]
# PCA with Maximum Component

# %%
from sklearn.decomposition import PCA

# Jumlah maksimum komponen = jumlah fitur
pca = PCA(n_components=X_scaled.shape[1])
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# Cumulative Explained Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

explained_variance = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Variance Threshold')
plt.title('Cumulative Explained Variance (CEV)')
plt.xlabel('Jumlah Komponen')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Variance Comparison

# %%
pca_variance_df = pd.DataFrame({
    'Komponen ke-': [f'PC{i+1}' for i in range(len(pca.explained_variance_ratio_))],
    'Explained Variance Ratio': pca.explained_variance_ratio_,
    'Cumulative Variance': explained_variance
})

pca_variance_df.head(10)  # Atau print semua
# Out:
#   Komponen ke-  Explained Variance Ratio  Cumulative Variance
# 0          PC1                  0.509886             0.509886
# 1          PC2                  0.113222             0.623107
# 2          PC3                  0.064693             0.687800
# 3          PC4                  0.044347             0.732147
# 4          PC5                  0.039698             0.771845
# 5          PC6                  0.030341             0.802186
# 6          PC7                  0.028578             0.830764
# 7          PC8                  0.025906             0.856670
# 8          PC9                  0.023020             0.879690
# 9         PC10                  0.021132             0.900822

# %% [markdown]
# Chosen N Component

# %%
thresholds = [0.95, 0.96, 0.97, 0.98, 0.99, 1.00]
epsilon = 1e-8

n_components_list = []

for threshold in thresholds:
    idx = np.argmax(explained_variance >= (threshold - epsilon))
    n_components = idx + 1
    n_components_list.append((threshold, n_components))

# Tampilkan hasilnya
for threshold, n in n_components_list:
    print(f"Untuk threshold {threshold*100:.0f}%, jumlah komponen: {n}")
# Out:
# Untuk threshold 95%, jumlah komponen: 14
# Untuk threshold 96%, jumlah komponen: 15
# Untuk threshold 97%, jumlah komponen: 16
# Untuk threshold 98%, jumlah komponen: 18
# Untuk threshold 99%, jumlah komponen: 21
# Untuk threshold 100%, jumlah komponen: 34

# %% [markdown]
# 10 Components for Classification Later

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.decomposition import PCA

# # Split dulu
# X_train_raw, X_test_raw, y_train, y_test = train_test_split(
#     X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
# )

# # Fit PCA hanya di training
# pca = PCA(n_components=8)
# X_train_pca = pca.fit_transform(X_train_raw)

# # Transform testing pakai PCA dari training
# X_test_pca = pca.transform(X_test_raw)

# %% [markdown]
# PC1 and PC2 Visualization

# %%
import matplotlib.pyplot as plt

# Ambil hanya dua komponen pertama dari PCA
pca_2d = PCA(n_components=2)
X_pca_2d = pca_2d.fit_transform(X_scaled)

# Buat DataFrame untuk visualisasi
pca_2d_df = pd.DataFrame(data=X_pca_2d, columns=["PC1", "PC2"])
pca_2d_df["defective"] = y_scaled.values

# Scatter plot
plt.figure(figsize=(8, 6))
colors = {0: 'skyblue', 1: 'salmon'}

for label in [0, 1]:
    subset = pca_2d_df[pca_2d_df["defective"] == label]
    plt.scatter(subset["PC1"], subset["PC2"], 
                label=f"Defective = {label}", 
                alpha=0.6, c=colors[label])

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Visualisasi PCA 2D berdasarkan label defective")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### t-SNE

# %% [markdown]
# t-SNE

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score, davies_bouldin_score
from parametric_tSNE import Parametric_tSNE


# Daftar nilai perplexity yang ingin diuji
perplexities = [5, 10, 30, 50]

plt.figure(figsize=(18, 12))

# Simpan hasil coherence metrics
coherence_results = []

for i, perplexity in enumerate(perplexities, 1):
    print(f"\n▶️ Perplexity = {perplexity}")
    
    # 1️⃣ Fit parametric t-SNE ke seluruh data
    ptSNE = Parametric_tSNE(X_scaled.shape[1], 2, perplexity, seed=42)
    ptSNE.fit(X_scaled)
    
    # 2️⃣ Transform data ke ruang embedding
    X_tsne = ptSNE.transform(X_scaled)

    # 3️⃣ Buat DataFrame untuk visualisasi
    tsne_df = pd.DataFrame(X_tsne, columns=["TSNE1", "TSNE2"])
    tsne_df["defective"] = y_scaled.values

    # 4️⃣ Plot
    plt.subplot(2, 2, i)
    for label in [0, 1]:
        subset = tsne_df[tsne_df["defective"] == label]
        plt.scatter(subset["TSNE1"], subset["TSNE2"], alpha=0.6, label=f"Defective = {label}")
    
    plt.title(f"Parametric t-SNE (Perplexity={perplexity})")
    plt.xlabel("TSNE1")
    plt.ylabel("TSNE2")
    plt.legend()
    plt.grid(True)
    
    # 5️⃣ Coherence evaluation: silhouette dan Davies-Bouldin
    silhouette = silhouette_score(X_tsne, y_scaled)
    db_index = davies_bouldin_score(X_tsne, y_scaled)
    
    print(f"  Silhouette Score : {silhouette:.4f}")
    print(f"  Davies-Bouldin Index : {db_index:.4f}")
    
    coherence_results.append({
        "Perplexity": perplexity,
        "Silhouette": silhouette,
        "Davies-Bouldin": db_index
    })

plt.tight_layout()
plt.show()
# Out:
# ▶️ Perplexity = 5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#   Silhouette Score : 0.0641
#   Davies-Bouldin Index : 3.1586
#
# ▶️ Perplexity = 10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#   Silhouette Score : 0.0608
#   Davies-Bouldin Index : 3.1618
#
# ▶️ Perplexity = 30
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#   Silhouette Score : 0.0608
#   Davies-Bouldin Index : 3.2118
#
# ▶️ Perplexity = 50
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#   Silhouette Score : 0.0601
#   Davies-Bouldin Index : 3.2088

# %% [markdown]
# Copy to clipboard

# %%
# Buat DataFrame dari hasil evaluasi
df_coherence = pd.DataFrame(coherence_results)

# Tampilkan
print("\n✅ Hasil Evaluasi Coherence untuk Tiap Perplexity:")
print(df_coherence.to_string(index=False))

df_coherence["Silhouette"] = df_coherence["Silhouette"].apply(lambda x: f"{x:.4f}".replace(".", ","))
df_coherence["Davies-Bouldin"] = df_coherence["Davies-Bouldin"].apply(lambda x: f"{x:.4f}".replace(".", ","))

# Salin ke clipboard untuk Excel (tanpa index, tab-sep)
df_coherence.to_clipboard(index=False, sep='\t')
# Out:
# ✅ Hasil Evaluasi Coherence untuk Tiap Perplexity:
#  Perplexity  Silhouette  Davies-Bouldin
#           5    0.064077        3.158640
#          10    0.060840        3.161821
#          30    0.060774        3.211812
#          50    0.060059        3.208817

# %% [markdown]
# ##### PCA + Classification

# %% [markdown]
# Single Learning and Ensemble Learning Imports

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %% [markdown]
# Model Train and Evaluation

# %%
# 1️⃣ Split data
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
)

# 2️⃣ Daftar nilai n_components dari PCA (misal dari threshold CEV 95%–100%)
n_components_list = [14, 15, 16, 18, 21] # coba 1 aja buat sebelum hyperparameter tuning

# 3️⃣ Model-model klasifikasi
models = { 
    "Logistic Regression": LogisticRegression(solver='saga', max_iter=1000, random_state=42),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", random_state=42)
}

results = []

# 4️⃣ Loop untuk setiap n_components
for n_comp in n_components_list:
    print(f"\n▶️ PCA: n_components={n_comp}")

    # Fit PCA di data train
    pca = PCA(n_components=n_comp)
    X_train_pca = pca.fit_transform(X_train_raw)
    X_test_pca = pca.transform(X_test_raw)

    for name, model in models.items():
        model.fit(X_train_pca, y_train)
        y_pred = model.predict(X_test_pca)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results.append({
            "n_components": n_comp,
            "Model": name,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"  {name}: acc={acc:.4f}, f1={f1:.4f}")

# 5️⃣ Simpan hasil ke DataFrame
df_results_pca = pd.DataFrame(results)
df_results_pca_sorted = df_results_pca.sort_values(by=["n_components", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Evaluasi PCA:")
print(df_results_pca_sorted.to_string(index=False))
# Out:
# ▶️ PCA: n_components=14
#   Logistic Regression: acc=0.6646, f1=0.6556
#   SVM: acc=0.7172, f1=0.7233
#   KNN: acc=0.7798, f1=0.7932
#   Random Forest: acc=0.8303, f1=0.8359
#   AdaBoost: acc=0.6889, f1=0.7004
#   Gradient Boosting: acc=0.7596, f1=0.7662
#   CatBoost: acc=0.8101, f1=0.8164
#   XGBoost: acc=0.8263, f1=0.8340
#
# ▶️ PCA: n_components=15
#   Logistic Regression: acc=0.6768, f1=0.6721
#   SVM: acc=0.7232, f1=0.7298
#   KNN: acc=0.7758, f1=0.7894
#   Random Forest: acc=0.8424, f1=0.8458
#   AdaBoost: acc=0.6747, f1=0.6625
#   Gradient Boosting: acc=0.7636, f1=0.7728
#   CatBoost: acc=0.8081, f1=0.8126
#   XGBoost: acc=0.8141, f1=0.8182
#
# ▶️ PCA: n_components=16
#   Logistic Regression: acc=0.6788, f1=0.6748
#   SVM: acc=0.7232, f1=0.7319
#   KNN: acc=0.7818, f1=0.7939
#   Random Forest: acc=0.8323, f1=0.8382
#   AdaBoost: acc=0.6747, f1=0.6625
#   Gradient Boosting: acc=0.7859, f1=0.7905
#   CatBoost: acc=0.8202, f1=0.8272
#   XGBoost: acc=0.8263, f1=0.8300
#
# ▶️ PCA: n_components=18
#   Logistic Regression: acc=0.6768, f1=0.6721
#   SVM: acc=0.7333, f1=0.7412
#   KNN: acc=0.7879, f1=0.7992
#   Random Forest: acc=0.8444, f1=0.8499
#   AdaBoost: acc=0.6747, f1=0.6625
#   Gradient Boosting: acc=0.7919, f1=0.7992
#   CatBoost: acc=0.8081, f1=0.8155
#   XGBoost: acc=0.8242, f1=0.8304
#
# ▶️ PCA: n_components=21
#   Logistic Regression: acc=0.6626, f1=0.6585
#   SVM: acc=0.7212, f1=0.7273
#   KNN: acc=0.7838, f1=0.7977
#   Random Forest: acc=0.8283, f1=0.8375
#   AdaBoost: acc=0.6747, f1=0.6523
#   Gradient Boosting: acc=0.7939, f1=0.8008
#   CatBoost: acc=0.8242, f1=0.8304
#   XGBoost: acc=0.8424, f1=0.8477
#
# ✅ Hasil Evaluasi PCA:
#  n_components               Model  Accuracy  Precision   Recall  F1-Score
#            14       Random Forest  0.830303   0.807547 0.866397  0.835938
#            14             XGBoost  0.826263   0.797048 0.874494  0.833977
#            14            CatBoost  0.810101   0.788679 0.846154  0.816406
#            14                 KNN  0.779798   0.746429 0.846154  0.793169
#            14   Gradient Boosting  0.759596   0.744275 0.789474  0.766208
#            14                 SVM  0.717172   0.706564 0.740891  0.723320
#            14            AdaBoost  0.688889   0.674157 0.728745  0.700389
#            14 Logistic Regression  0.664646   0.672340 0.639676  0.655602
#            15       Random Forest  0.842424   0.826255 0.866397  0.845850
#            15             XGBoost  0.814141   0.799228 0.838057  0.818182
#            15            CatBoost  0.808081   0.792308 0.834008  0.812623
#            15                 KNN  0.775758   0.742857 0.842105  0.789374
#            15   Gradient Boosting  0.763636   0.742537 0.805668  0.772816
#            15                 SVM  0.723232   0.711538 0.748988  0.729783
#            15 Logistic Regression  0.676768   0.680498 0.663968  0.672131
#            15            AdaBoost  0.674747   0.686957 0.639676  0.662474
#            16       Random Forest  0.832323   0.808271 0.870445  0.838207
#            16             XGBoost  0.826263   0.810811 0.850202  0.830040
#            16            CatBoost  0.820202   0.794776 0.862348  0.827184
#            16                 KNN  0.781818   0.750903 0.842105  0.793893
#            16   Gradient Boosting  0.785859   0.772201 0.809717  0.790514
#            16                 SVM  0.723232   0.708333 0.757085  0.731898
#            16 Logistic Regression  0.678788   0.681818 0.668016  0.674847
#            16            AdaBoost  0.674747   0.686957 0.639676  0.662474
#            18       Random Forest  0.844444   0.819549 0.882591  0.849903
#            18             XGBoost  0.824242   0.800752 0.862348  0.830409
#            18            CatBoost  0.808081   0.783582 0.850202  0.815534
#            18                 KNN  0.787879   0.757246 0.846154  0.799235
#            18   Gradient Boosting  0.791919   0.770677 0.829960  0.799220
#            18                 SVM  0.733333   0.718631 0.765182  0.741176
#            18 Logistic Regression  0.676768   0.680498 0.663968  0.672131
#            18            AdaBoost  0.674747   0.686957 0.639676  0.662474
#            21             XGBoost  0.842424   0.818868 0.878543  0.847656
#            21       Random Forest  0.828283   0.793478 0.886640  0.837476
#            21            CatBoost  0.824242   0.800752 0.862348  0.830409
#            21   Gradient Boosting  0.793939   0.773585 0.829960  0.800781
#            21                 KNN  0.783838   0.748227 0.854251  0.797732
#            21                 SVM  0.721212   0.710425 0.744939  0.727273
#            21 Logistic Regression  0.662626   0.665289 0.651822  0.658487
#            21            AdaBoost  0.674747   0.699074 0.611336  0.652268

# %%
n_components = 21
df_filtered = df_results_pca[df_results_pca["n_components"] == n_components]

# Drop kolom yang tidak perlu disalin
df_results_sorted = df_filtered.sort_values(by="F1-Score", ascending=False)
df_to_copy = df_results_sorted.drop(columns=["n_components"])

# Tampilkan ke terminal
print(df_to_copy.to_string(index=False))

# Salin ke clipboard tanpa kolom tambahan
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
#               Model  Accuracy  Precision   Recall  F1-Score
#             XGBoost  0.842424   0.818868 0.878543  0.847656
#       Random Forest  0.828283   0.793478 0.886640  0.837476
#            CatBoost  0.824242   0.800752 0.862348  0.830409
#   Gradient Boosting  0.793939   0.773585 0.829960  0.800781
#                 KNN  0.783838   0.748227 0.854251  0.797732
#                 SVM  0.721212   0.710425 0.744939  0.727273
# Logistic Regression  0.662626   0.665289 0.651822  0.658487
#            AdaBoost  0.674747   0.699074 0.611336  0.652268

# %% [markdown]
# ##### Parametric t-SNE + Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

from parametric_tSNE import Parametric_tSNE
import pandas as pd

# 1️⃣ Split data
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
)

# 2️⃣ Kombinasi output_dim yang diambil dari CEV PCA
output_dims = [14, 15, 16, 18, 21] # sebelum hyperparameter tuning, coba satu dulu, abis itu langsung tuning
perplexity = 10

# 3️⃣ Model-model klasifikasi
models = { 
    "Logistic Regression": LogisticRegression(solver='saga', max_iter=1000, random_state=42),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", random_state=42)
}

results = []

# 4️⃣ Loop semua output_dim
for out_dim in output_dims:
    print(f"\n▶️ Parametric t-SNE: output_dim={out_dim}, perplexity={perplexity}")
    
    # Fit t-SNE hanya pada data train
    ptSNE = Parametric_tSNE(X_train_raw.shape[1], out_dim, perplexity, seed=42)
    ptSNE.fit(X_train_raw)
    
    # Transform data
    X_train_tsne = ptSNE.transform(X_train_raw)
    X_test_tsne = ptSNE.transform(X_test_raw)
    
    for name, model in models.items():
        model.fit(X_train_tsne, y_train)
        y_pred = model.predict(X_test_tsne)
        
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        
        results.append({
            "Output Dim": out_dim,
            "Perplexity": perplexity,
            "Model": name,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"  {name}: acc={acc:.4f}, f1={f1:.4f}")

# 5️⃣ Simpan hasil ke DataFrame
df_results = pd.DataFrame(results)
df_results_sorted = df_results.sort_values(by=["Output Dim", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Evaluasi Parametric t-SNE:")
print(df_results_sorted.to_string(index=False))

# Opsional: Simpan ke CSV
# df_results_sorted.to_csv("parametric_tsne_results.csv", index=False)
# Out:
# ▶️ Parametric t-SNE: output_dim=14, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#   Logistic Regression: acc=0.6485, f1=0.6390
#   SVM: acc=0.7010, f1=0.7063
#   KNN: acc=0.7313, f1=0.7397
#   Random Forest: acc=0.7636, f1=0.7754
#   AdaBoost: acc=0.6222, f1=0.6267
#   Gradient Boosting: acc=0.7253, f1=0.7333
#   CatBoost: acc=0.7475, f1=0.7535
#   XGBoost: acc=0.7778, f1=0.7876
#
# ▶️ Parametric t-SNE: output_dim=15, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#   Logistic Regression: acc=0.6626, f1=0.6514
#   SVM: acc=0.7071, f1=0.7106
#   KNN: acc=0.7434, f1=0.7544
#   Random Forest: acc=0.7535, f1=0.7645
#   AdaBoost: acc=0.6727, f1=0.6653
#   Gradient Boosting: acc=0.7030, f1=0.6994
#   CatBoost: acc=0.7293, f1=0.7352
#   XGBoost: acc=0.7515, f1=0.7555
#
# ▶️ Parametric t-SNE: output_dim=16, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#   Logistic Regression: acc=0.6525, f1=0.6402
#   SVM: acc=0.7030, f1=0.7078
#   KNN: acc=0.7293, f1=0.7393
#   Random Forest: acc=0.7717, f1=0.7839
#   AdaBoost: acc=0.6788, f1=0.6735
#   Gradient Boosting: acc=0.7333, f1=0.7452
#   CatBoost: acc=0.7434, f1=0.7515
#   XGBoost: acc=0.7576, f1=0.7692
#
# ▶️ Parametric t-SNE: output_dim=18, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#   Logistic Regression: acc=0.6606, f1=0.6485
#   SVM: acc=0.7051, f1=0.7103
#   KNN: acc=0.7455, f1=0.7539
#   Random Forest: acc=0.7697, f1=0.7808
#   AdaBoost: acc=0.6768, f1=0.6838
#   Gradient Boosting: acc=0.7131, f1=0.7194
#   CatBoost: acc=0.7394, f1=0.7485
#   XGBoost: acc=0.7556, f1=0.7641
#
# ▶️ Parametric t-SNE: output_dim=21, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#   Logistic Regression: acc=0.6606, f1=0.6500
#   SVM: acc=0.7051, f1=0.7103
#   KNN: acc=0.7515, f1=0.7583
#   Random Forest: acc=0.7758, f1=0.7869
#   AdaBoost: acc=0.6424, f1=0.6603
#   Gradient Boosting: acc=0.7152, f1=0.7262
#   CatBoost: acc=0.7354, f1=0.7446
#   XGBoost: acc=0.7778, f1=0.7901
#
# ✅ Hasil Evaluasi Parametric t-SNE:
#  Output Dim  Perplexity               Model  Accuracy  Precision   Recall  F1-Score
#          14          10             XGBoost  0.777778   0.752768 0.825911  0.787645
#          14          10       Random Forest  0.763636   0.737226 0.817814  0.775432
#          14          10            CatBoost  0.747475   0.734615 0.773279  0.753452
#          14          10                 KNN  0.731313   0.715909 0.765182  0.739726
#          14          10   Gradient Boosting  0.725253   0.711027 0.757085  0.733333
#          14          10                 SVM  0.701010   0.692607 0.720648  0.706349
#          14          10 Logistic Regression  0.648485   0.655319 0.623482  0.639004
#          14          10            AdaBoost  0.622222   0.618110 0.635628  0.626747
#          15          10       Random Forest  0.753535   0.730627 0.801619  0.764479
#          15          10             XGBoost  0.751515   0.742188 0.769231  0.755467
#          15          10                 KNN  0.743434   0.722222 0.789474  0.754352
#          15          10            CatBoost  0.729293   0.718147 0.753036  0.735178
#          15          10                 SVM  0.707071   0.700787 0.720648  0.710579
#          15          10   Gradient Boosting  0.703030   0.706612 0.692308  0.699387
#          15          10            AdaBoost  0.672727   0.679325 0.651822  0.665289
#          15          10 Logistic Regression  0.662626   0.672414 0.631579  0.651357
#          16          10       Random Forest  0.771717   0.742754 0.829960  0.783939
#          16          10             XGBoost  0.757576   0.732601 0.809717  0.769231
#          16          10            CatBoost  0.743434   0.727273 0.777328  0.751468
#          16          10   Gradient Boosting  0.733333   0.712177 0.781377  0.745174
#          16          10                 KNN  0.729293   0.711610 0.769231  0.739300
#          16          10                 SVM  0.703030   0.695312 0.720648  0.707753
#          16          10            AdaBoost  0.678788   0.683333 0.663968  0.673511
#          16          10 Logistic Regression  0.652525   0.662338 0.619433  0.640167
#          18          10       Random Forest  0.769697   0.743590 0.821862  0.780769
#          18          10             XGBoost  0.755556   0.736842 0.793522  0.764133
#          18          10                 KNN  0.745455   0.728302 0.781377  0.753906
#          18          10            CatBoost  0.739394   0.721805 0.777328  0.748538
#          18          10   Gradient Boosting  0.713131   0.702703 0.736842  0.719368
#          18          10                 SVM  0.705051   0.696498 0.724696  0.710317
#          18          10            AdaBoost  0.676768   0.667954 0.700405  0.683794
#          18          10 Logistic Regression  0.660606   0.670996 0.627530  0.648536
#          21          10             XGBoost  0.777778   0.747292 0.838057  0.790076
#          21          10       Random Forest  0.775758   0.748175 0.829960  0.786948
#          21          10                 KNN  0.751515   0.736641 0.781377  0.758350
#          21          10            CatBoost  0.735354   0.718045 0.773279  0.744639
#          21          10   Gradient Boosting  0.715152   0.697761 0.757085  0.726214
#          21          10                 SVM  0.705051   0.696498 0.724696  0.710317
#          21          10            AdaBoost  0.642424   0.627737 0.696356  0.660269
#          21          10 Logistic Regression  0.660606   0.669528 0.631579  0.650000

# %% [markdown]
# Copy to clipboard

# %%
out_dim = 21
df_filtered = df_results_sorted[df_results_sorted["Output Dim"] == out_dim]

# Drop kolom yang tidak perlu disalin
df_to_copy = df_filtered.drop(columns=["Output Dim", "Perplexity"])

# Tampilkan ke terminal
print(df_to_copy.to_string(index=False))

# Salin ke clipboard tanpa kolom tambahan
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
#               Model  Accuracy  Precision   Recall  F1-Score
#             XGBoost  0.777778   0.747292 0.838057  0.790076
#       Random Forest  0.775758   0.748175 0.829960  0.786948
#                 KNN  0.751515   0.736641 0.781377  0.758350
#            CatBoost  0.735354   0.718045 0.773279  0.744639
#   Gradient Boosting  0.715152   0.697761 0.757085  0.726214
#                 SVM  0.705051   0.696498 0.724696  0.710317
#            AdaBoost  0.642424   0.627737 0.696356  0.660269
# Logistic Regression  0.660606   0.669528 0.631579  0.650000

# %% [markdown]
# ##### Hyperparameter Tuning (Without PCA and t-SNE)

# %%
param_grids = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10],
        "penalty": ["l1", "l2", None]
    },
    "SVM": {
        "C": [0.1, 1, 10],
        "kernel": ["linear", "rbf"]
    },
    "KNN": {
        "n_neighbors": [3, 5, 7, 9]
    },
    "Random Forest": {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 5, 10]
    },
    "AdaBoost": {
        "n_estimators": [50, 100, 200],
        "learning_rate": [0.5, 1.0]
    },
    "Gradient Boosting": {
        "n_estimators": [50, 100],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5]
    },
    "CatBoost": {
        "iterations": [100, 200],
        "learning_rate": [0.03, 0.1],
        "depth": [3, 5, 7]
    },
    "XGBoost": {
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5, 7]
    }
}

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Split data dari X_scaled (tanpa PCA/t-SNE)
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
)

# Simpan hasil tuning tanpa PCA/t-SNE
results_no_reduction_tuned = []

for name, model in models.items():
    print(f"Tuning {name} (No Dimensionality Reduction)...")
    grid = GridSearchCV(
        model,
        param_grids[name],
        cv=StratifiedKFold(n_splits=5),
        scoring='f1',
        n_jobs=-1
    )
    grid.fit(X_train_raw, y_train)

    best_model = grid.best_estimator_
    y_pred = best_model.predict(X_test_raw)

    results_no_reduction_tuned.append({
        "Model": name,
        "Best Params": grid.best_params_,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1-Score": f1_score(y_test, y_pred)
    })

    print(f"\n==== {name} (Tuned - No Dimensionality Reduction) ====")
    print("Best Params:", grid.best_params_)
    print(classification_report(y_test, y_pred))

# Konversi ke DataFrame
import pandas as pd
df_results_no_reduction_tuned = pd.DataFrame(results_no_reduction_tuned)
print("\n✅ Hasil evaluasi (tanpa PCA/t-SNE):")
print(df_results_no_reduction_tuned)
# Out:
# Tuning Logistic Regression (No Dimensionality Reduction)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (Tuned - No Dimensionality Reduction) ====
# Best Params: {'C': 10, 'penalty': 'l2'}
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       248
#            1       0.68      0.65      0.67       247
#
#     accuracy                           0.67       495
#    macro avg       0.67      0.67      0.67       495
# weighted avg       0.67      0.67      0.67       495
#
# Tuning SVM (No Dimensionality Reduction)...
#
# ==== SVM (Tuned - No Dimensionality Reduction) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       248
#            1       0.75      0.78      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
# Tuning KNN (No Dimensionality Reduction)...
#
# ==== KNN (Tuned - No Dimensionality Reduction) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       248
#            1       0.76      0.84      0.80       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
# Tuning Random Forest (No Dimensionality Reduction)...
#
# ==== Random Forest (Tuned - No Dimensionality Reduction) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       248
#            1       0.84      0.88      0.86       247
#
#     accuracy                           0.86       495
#    macro avg       0.86      0.86      0.86       495
# weighted avg       0.86      0.86      0.86       495
#
# Tuning AdaBoost (No Dimensionality Reduction)...
#
# ==== AdaBoost (Tuned - No Dimensionality Reduction) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76       248
#            1       0.77      0.75      0.76       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
# Tuning Gradient Boosting (No Dimensionality Reduction)...
#
# ==== Gradient Boosting (Tuned - No Dimensionality Reduction) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       248
#            1       0.84      0.84      0.84       247
#
#     accuracy                           0.84       495
#    macro avg       0.84      0.84      0.84       495
# weighted avg       0.84      0.84      0.84       495
#
# Tuning CatBoost (No Dimensionality Reduction)...
#
# ==== CatBoost (Tuned - No Dimensionality Reduction) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       248
#            1       0.84      0.86      0.85       247
#
#     accuracy                           0.85       495
#    macro avg       0.85      0.85      0.85       495
# weighted avg       0.85      0.85      0.85       495
#
# Tuning XGBoost (No Dimensionality Reduction)...
#
# ==== XGBoost (Tuned - No Dimensionality Reduction) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.85       248
#            1       0.83      0.88      0.85       247
#
#     accuracy                           0.85       495
#    macro avg       0.85      0.85      0.85       495
# weighted avg       0.85      0.85      0.85       495
#
#
# ✅ Hasil evaluasi (tanpa PCA/t-SNE):
#                  Model                                        Best Params  \
# 0  Logistic Regression                         {'C': 10, 'penalty': 'l2'}
# 1                  SVM                         {'C': 10, 'kernel': 'rbf'}
# 2                  KNN                                 {'n_neighbors': 3}
# 3        Random Forest           {'max_depth': None, 'n_estimators': 200}
# 4             AdaBoost        {'learning_rate': 1.0, 'n_estimators': 200}
# 5    Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 6             CatBoost  {'depth': 7, 'iterations': 200, 'learning_rate...
# 7              XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...
#
#    Accuracy  Precision    Recall  F1-Score
# 0  0.672727   0.679325  0.651822  0.665289
# 1  0.763636   0.753906  0.781377  0.767396
# 2  0.789899   0.763838  0.838057  0.799228
# 3  0.856566   0.838462  0.882591  0.859961
# 4  0.761616   0.765432  0.753036  0.759184
# 5  0.840404   0.838710  0.842105  0.840404
# 6  0.846465   0.835294  0.862348  0.848606
# 7  0.850505   0.831418  0.878543  0.854331

# %%
# Tampilkan dalam bentuk DataFrame
df_results_no_reduction_tuned = pd.DataFrame(results_no_reduction_tuned)

# Urutkan berdasarkan F1-Score tertinggi
df_results_no_reduction_tuned_sorted = df_results_no_reduction_tuned.sort_values(by="F1-Score", ascending=False)

# Tampilkan hasil akhir
print("\n✅ Hasil Evaluasi Model Tanpa PCA dan t-SNE Tuned:")
print(df_results_no_reduction_tuned_sorted.to_string(index=False))

df_results_no_reduction_tuned_sorted.to_clipboard(index=False, excel=True, sep='\t')
# Out:
# ✅ Hasil Evaluasi Model Tanpa PCA dan t-SNE Tuned:
#               Model                                                 Best Params  Accuracy  Precision   Recall  F1-Score
#       Random Forest                    {'max_depth': None, 'n_estimators': 200}  0.856566   0.838462 0.882591  0.859961
#             XGBoost {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.850505   0.831418 0.878543  0.854331
#            CatBoost       {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.846465   0.835294 0.862348  0.848606
#   Gradient Boosting {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.840404   0.838710 0.842105  0.840404
#                 KNN                                          {'n_neighbors': 3}  0.789899   0.763838 0.838057  0.799228
#                 SVM                                  {'C': 10, 'kernel': 'rbf'}  0.763636   0.753906 0.781377  0.767396
#            AdaBoost                 {'learning_rate': 1.0, 'n_estimators': 200}  0.761616   0.765432 0.753036  0.759184
# Logistic Regression                                  {'C': 10, 'penalty': 'l2'}  0.672727   0.679325 0.651822  0.665289

# %% [markdown]
# ##### Hyperparameter Tuning After PCA

# %% [markdown]
# Parameter Grids

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid untuk setiap model
param_grids = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10]
    },
    "SVM": {
        "C": [0.1, 1, 10],
        "kernel": ["linear", "rbf"]
    },
    "KNN": {
        "n_neighbors": [3, 5, 7, 9]
    },
    "Random Forest": {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 5, 10]
    },
    "AdaBoost": {
        "n_estimators": [50, 100, 200],
        "learning_rate": [0.5, 1.0]
    },
    "Gradient Boosting": {
        "n_estimators": [50, 100],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5]
    },
    "CatBoost": {
        "iterations": [100, 200],
        "learning_rate": [0.03, 0.1],
        "depth": [3, 5, 7]
    },
    "XGBoost": {
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5, 7]
    }
}

# %% [markdown]
# Lakukan GridsearchCV

# %%
from sklearn.model_selection import StratifiedKFold

# 2️⃣ Daftar n_components dari threshold CEV PCA
n_components_list = [14, 15, 16, 18, 21, 34]

# 3️⃣ Simpan hasil tuning
results_pca_tuned = []

# 4️⃣ Loop semua n_components
for n_comp in n_components_list:
    print(f"\n🎯 PCA n_components={n_comp}")
    
    pca = PCA(n_components=n_comp)
    X_train_pca = pca.fit_transform(X_train_raw)
    X_test_pca = pca.transform(X_test_raw)

    for name, model in models.items():
        print(f"\nTuning {name} (PCA)...")
        grid = GridSearchCV(
            model,
            param_grids[name],
            cv=StratifiedKFold(n_splits=5),
            scoring='f1',
            n_jobs=-1
        )
        grid.fit(X_train_pca, y_train)

        best_model = grid.best_estimator_
        y_pred = best_model.predict(X_test_pca)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results_pca_tuned.append({
            "n_components": n_comp,
            "Model": name,
            "Best Params": grid.best_params_,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"\n==== {name} (PCA + Tuned) ====")
        print("Best Params:", grid.best_params_)
        print(classification_report(y_test, y_pred))

# 5️⃣ Simpan hasil ke DataFrame
df_results_pca_tuned = pd.DataFrame(results_pca_tuned)
df_results_pca_tuned_sorted = df_results_pca_tuned.sort_values(by=["n_components", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Hyperparameter Tuning PCA:")
print(df_results_pca_tuned_sorted.to_string(index=False))
# Out:
# 🎯 PCA n_components=14
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67       248
#            1       0.67      0.64      0.65       247
#
#     accuracy                           0.66       495
#    macro avg       0.66      0.66      0.66       495
# weighted avg       0.66      0.66      0.66       495
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75       248
#            1       0.74      0.78      0.76       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78       248
#            1       0.76      0.85      0.80       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       248
#            1       0.80      0.87      0.83       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.70      0.68      0.69       248
#            1       0.69      0.71      0.70       247
#
#     accuracy                           0.69       495
#    macro avg       0.70      0.69      0.69       495
# weighted avg       0.70      0.69      0.69       495
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80       248
#            1       0.78      0.86      0.82       247
#
#     accuracy                           0.81       495
#    macro avg       0.81      0.81      0.81       495
# weighted avg       0.81      0.81      0.81       495
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       248
#            1       0.78      0.85      0.81       247
#
#     accuracy                           0.81       495
#    macro avg       0.81      0.81      0.81       495
# weighted avg       0.81      0.81      0.81       495
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       248
#            1       0.77      0.81      0.79       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# 🎯 PCA n_components=15
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.69       248
#            1       0.68      0.67      0.68       247
#
#     accuracy                           0.68       495
#    macro avg       0.68      0.68      0.68       495
# weighted avg       0.68      0.68      0.68       495
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.75       248
#            1       0.74      0.77      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       248
#            1       0.76      0.84      0.80       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       248
#            1       0.81      0.87      0.84       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71       248
#            1       0.71      0.70      0.70       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78       248
#            1       0.77      0.82      0.79       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81       248
#            1       0.80      0.85      0.83       247
#
#     accuracy                           0.82       495
#    macro avg       0.82      0.82      0.82       495
# weighted avg       0.82      0.82      0.82       495
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       248
#            1       0.81      0.87      0.84       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# 🎯 PCA n_components=16
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       248
#            1       0.68      0.66      0.67       247
#
#     accuracy                           0.67       495
#    macro avg       0.67      0.67      0.67       495
# weighted avg       0.67      0.67      0.67       495
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76       248
#            1       0.75      0.78      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78       248
#            1       0.76      0.85      0.80       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       248
#            1       0.81      0.87      0.84       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.70       248
#            1       0.70      0.67      0.69       247
#
#     accuracy                           0.69       495
#    macro avg       0.70      0.69      0.69       495
# weighted avg       0.70      0.69      0.69       495
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       248
#            1       0.79      0.86      0.82       247
#
#     accuracy                           0.81       495
#    macro avg       0.82      0.81      0.81       495
# weighted avg       0.82      0.81      0.81       495
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       248
#            1       0.81      0.86      0.83       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       248
#            1       0.80      0.87      0.83       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# 🎯 PCA n_components=18
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.68       248
#            1       0.68      0.67      0.67       247
#
#     accuracy                           0.68       495
#    macro avg       0.68      0.68      0.68       495
# weighted avg       0.68      0.68      0.68       495
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76       248
#            1       0.76      0.78      0.77       247
#
#     accuracy                           0.77       495
#    macro avg       0.77      0.77      0.77       495
# weighted avg       0.77      0.77      0.77       495
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78       248
#            1       0.77      0.85      0.81       247
#
#     accuracy                           0.80       495
#    macro avg       0.80      0.80      0.80       495
# weighted avg       0.80      0.80      0.80       495
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       248
#            1       0.80      0.87      0.83       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.71       248
#            1       0.71      0.68      0.69       247
#
#     accuracy                           0.70       495
#    macro avg       0.70      0.70      0.70       495
# weighted avg       0.70      0.70      0.70       495
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       248
#            1       0.79      0.85      0.82       247
#
#     accuracy                           0.81       495
#    macro avg       0.82      0.81      0.81       495
# weighted avg       0.82      0.81      0.81       495
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       248
#            1       0.81      0.87      0.84       247
#
#     accuracy                           0.83       495
#    macro avg       0.84      0.83      0.83       495
# weighted avg       0.84      0.83      0.83       495
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       248
#            1       0.83      0.87      0.85       247
#
#     accuracy                           0.84       495
#    macro avg       0.84      0.84      0.84       495
# weighted avg       0.84      0.84      0.84       495
#
#
# 🎯 PCA n_components=21
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.66       248
#            1       0.66      0.66      0.66       247
#
#     accuracy                           0.66       495
#    macro avg       0.66      0.66      0.66       495
# weighted avg       0.66      0.66      0.66       495
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77       248
#            1       0.77      0.78      0.77       247
#
#     accuracy                           0.77       495
#    macro avg       0.77      0.77      0.77       495
# weighted avg       0.77      0.77      0.77       495
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78       248
#            1       0.76      0.84      0.80       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81       248
#            1       0.79      0.87      0.83       247
#
#     accuracy                           0.82       495
#    macro avg       0.83      0.82      0.82       495
# weighted avg       0.83      0.82      0.82       495
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72       248
#            1       0.72      0.70      0.71       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82       248
#            1       0.80      0.87      0.83       247
#
#     accuracy                           0.83       495
#    macro avg       0.83      0.83      0.83       495
# weighted avg       0.83      0.83      0.83       495
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       248
#            1       0.81      0.89      0.85       247
#
#     accuracy                           0.84       495
#    macro avg       0.84      0.84      0.84       495
# weighted avg       0.84      0.84      0.84       495
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       248
#            1       0.82      0.89      0.85       247
#
#     accuracy                           0.85       495
#    macro avg       0.85      0.85      0.85       495
# weighted avg       0.85      0.85      0.85       495
#
#
# 🎯 PCA n_components=34
#
# Tuning Logistic Regression (PCA)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       248
#            1       0.68      0.65      0.67       247
#
#     accuracy                           0.67       495
#    macro avg       0.67      0.67      0.67       495
# weighted avg       0.67      0.67      0.67       495
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       248
#            1       0.75      0.78      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       248
#            1       0.76      0.84      0.80       247
#
#     accuracy                           0.79       495
#    macro avg       0.79      0.79      0.79       495
# weighted avg       0.79      0.79      0.79       495
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       248
#            1       0.81      0.89      0.85       247
#
#     accuracy                           0.84       495
#    macro avg       0.85      0.84      0.84       495
# weighted avg       0.85      0.84      0.84       495
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71       248
#            1       0.71      0.71      0.71       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       248
#            1       0.80      0.85      0.82       247
#
#     accuracy                           0.82       495
#    macro avg       0.82      0.82      0.82       495
# weighted avg       0.82      0.82      0.82       495
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.84       248
#            1       0.81      0.89      0.85       247
#
#     accuracy                           0.84       495
#    macro avg       0.85      0.84      0.84       495
# weighted avg       0.85      0.84      0.84       495
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       248
#            1       0.82      0.89      0.85       247
#
#     accuracy                           0.85       495
#    macro avg       0.85      0.85      0.85       495
# weighted avg       0.85      0.85      0.85       495
#
#
# ✅ Hasil Hyperparameter Tuning PCA:
#  n_components               Model                                                  Best Params  Accuracy  Precision   Recall  F1-Score
#            14       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.826263   0.801498 0.866397  0.832685
#            14   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.808081   0.779412 0.858300  0.816956
#            14            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.806061   0.782772 0.846154  0.813230
#            14                 KNN                                           {'n_neighbors': 3}  0.787879   0.757246 0.846154  0.799235
#            14             XGBoost {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200}  0.787879   0.773077 0.813765  0.792899
#            14                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.755556   0.744186 0.777328  0.760396
#            14            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.694949   0.687500 0.712551  0.699801
#            14 Logistic Regression                                                    {'C': 10}  0.662626   0.669492 0.639676  0.654244
#            15       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.830303   0.807547 0.866397  0.835938
#            15             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.830303   0.807547 0.866397  0.835938
#            15            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.820202   0.799242 0.854251  0.825832
#            15                 KNN                                           {'n_neighbors': 3}  0.789899   0.761905 0.842105  0.800000
#            15   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.787879   0.770992 0.817814  0.793713
#            15                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.753535   0.743191 0.773279  0.757937
#            15            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.709091   0.713693 0.696356  0.704918
#            15 Logistic Regression                                                    {'C': 10}  0.680808   0.684647 0.668016  0.676230
#            16       Random Forest                     {'max_depth': None, 'n_estimators': 100}  0.832323   0.808271 0.870445  0.838207
#            16             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.826263   0.801498 0.866397  0.832685
#            16            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.826263   0.806084 0.858300  0.831373
#            16   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.814141   0.788104 0.858300  0.821705
#            16                 KNN                                           {'n_neighbors': 3}  0.789899   0.758123 0.850202  0.801527
#            16                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.761616   0.750973 0.781377  0.765873
#            16            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.694949   0.703390 0.672065  0.687371
#            16 Logistic Regression                                                    {'C': 10}  0.674747   0.677686 0.663968  0.670757
#            18             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.842424   0.826255 0.866397  0.845850
#            18            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.834343   0.808989 0.874494  0.840467
#            18       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.826263   0.801498 0.866397  0.832685
#            18   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.814141   0.792453 0.850202  0.820312
#            18                 KNN                                           {'n_neighbors': 3}  0.795960   0.766423 0.850202  0.806142
#            18                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.767677   0.759843 0.781377  0.770459
#            18            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.701010   0.708861 0.680162  0.694215
#            18 Logistic Regression                                                    {'C': 10}  0.678788   0.681818 0.668016  0.674847
#            21             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.846465   0.820225 0.886640  0.852140
#            21            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.838384   0.808118 0.886640  0.845560
#            21   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.828283   0.804511 0.866397  0.834308
#            21       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.822222   0.791209 0.874494  0.830769
#            21                 KNN                                           {'n_neighbors': 3}  0.791919   0.764706 0.842105  0.801541
#            21                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.771717   0.765873 0.781377  0.773547
#            21            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.713131   0.717842 0.700405  0.709016
#            21 Logistic Regression                                                   {'C': 0.1}  0.660606   0.661224 0.655870  0.658537
#            34             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.848485   0.818519 0.894737  0.854932
#            34            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.844444   0.812500 0.894737  0.851638
#            34       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.842424   0.814126 0.886640  0.848837
#            34   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.818182   0.796226 0.854251  0.824219
#            34                 KNN                                           {'n_neighbors': 3}  0.789899   0.763838 0.838057  0.799228
#            34                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.763636   0.753906 0.781377  0.767396
#            34            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.709091   0.708502 0.708502  0.708502
#            34 Logistic Regression                                                    {'C': 10}  0.672727   0.679325 0.651822  0.665289

# %% [markdown]
# Copy to Clipboard

# %%
n_target = 34

# Filter berdasarkan n_components
df_filtered = df_results_pca_tuned_sorted[df_results_pca_tuned_sorted["n_components"] == n_target]

# Drop kolom yang tidak ingin disalin
df_to_copy = df_filtered.drop(columns=["n_components"])

# Tampilkan ke terminal
print(f"\n📋 Hasil untuk n_components = {n_target}:")
print(df_to_copy.to_string(index=False))

# Salin ke clipboard agar bisa langsung ditempel ke Excel
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
# 📋 Hasil untuk n_components = 34:
#               Model                                                 Best Params  Accuracy  Precision   Recall  F1-Score
#             XGBoost {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.848485   0.818519 0.894737  0.854932
#            CatBoost       {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.844444   0.812500 0.894737  0.851638
#       Random Forest                    {'max_depth': None, 'n_estimators': 200}  0.842424   0.814126 0.886640  0.848837
#   Gradient Boosting {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.818182   0.796226 0.854251  0.824219
#                 KNN                                          {'n_neighbors': 3}  0.789899   0.763838 0.838057  0.799228
#                 SVM                                  {'C': 10, 'kernel': 'rbf'}  0.763636   0.753906 0.781377  0.767396
#            AdaBoost                 {'learning_rate': 1.0, 'n_estimators': 200}  0.709091   0.708502 0.708502  0.708502
# Logistic Regression                                                   {'C': 10}  0.672727   0.679325 0.651822  0.665289

# %% [markdown]
# ##### Hyperparameter Tuning After t-SNE

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score
import pandas as pd

# 1️⃣ Konfigurasi kombinasi
output_dims = [14, 15, 16, 18, 21, 34]
perplexity = 10

# 3️⃣ Simpan hasil tuning semua output_dim
results_tsne_tuned = []

for out_dim in output_dims:
    print(f"\n🎯 Parametric t-SNE output_dim={out_dim}, perplexity={perplexity}")
    
    # Buat dan fit Parametric t-SNE
    ptSNE = Parametric_tSNE(num_inputs=X_scaled.shape[1], num_outputs=out_dim, perplexities=perplexity, seed=42)
    ptSNE.fit(X_train_raw)

    X_train_tsne = ptSNE.transform(X_train_raw)
    X_test_tsne = ptSNE.transform(X_test_raw)

    for name, model in models.items():
        if name == "SVM":
            print("\n▶️ Skip GridSearch for SVM. Use best param from PCA!")
            best_params_svm_pca = {
                "C": 10,
                "kernel": "rbf"
            }
            svm_model = SVC(**best_params_svm_pca)
            svm_model.fit(X_train_tsne, y_train)
            y_pred = svm_model.predict(X_test_tsne)

            acc = accuracy_score(y_test, y_pred)
            prec = precision_score(y_test, y_pred)
            rec = recall_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred)

            results_tsne_tuned.append({
                "Output Dim": out_dim,
                "Perplexity": perplexity,
                "Model": name,
                "Best Params": best_params_svm_pca,
                "Accuracy": acc,
                "Precision": prec,
                "Recall": rec,
                "F1-Score": f1
            })

            print(f"\n==== {name} (Parametric t-SNE + Best Param PCA) ====")
            print("Best Params:", best_params_svm_pca)
            print(classification_report(y_test, y_pred))
            continue

        print(f"\nTuning {name} (Parametric t-SNE)...")
        grid = GridSearchCV(
            model,
            param_grids[name],
            cv=StratifiedKFold(n_splits=5),
            scoring='f1',
            n_jobs=-1
        )
        grid.fit(X_train_tsne, y_train)

        best_model = grid.best_estimator_
        y_pred = best_model.predict(X_test_tsne)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results_tsne_tuned.append({
            "Output Dim": out_dim,
            "Perplexity": perplexity,
            "Model": name,
            "Best Params": grid.best_params_,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"\n==== {name} (Parametric t-SNE + Tuned) ====")
        print("Best Params:", grid.best_params_)
        print(classification_report(y_test, y_pred))

# 4️⃣ Simpan hasil tuning ke DataFrame
df_results_tsne_tuned = pd.DataFrame(results_tsne_tuned)
df_results_tsne_tuned_sorted = df_results_tsne_tuned.sort_values(by=["Output Dim", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Hyperparameter Tuning Parametric t-SNE:")
print(df_results_tsne_tuned_sorted.to_string(index=False))

# 5️⃣ Simpan ke file CSV (opsional)
# df_results_tsne_tuned_sorted.to_csv("parametric_tsne_tuned_results.csv", index=False)
# Out:
# 🎯 Parametric t-SNE output_dim=14, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       248
#            1       0.68      0.66      0.67       247
#
#     accuracy                           0.67       495
#    macro avg       0.67      0.67      0.67       495
# weighted avg       0.67      0.67      0.67       495
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       248
#            1       0.69      0.73      0.71       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.70       495
# weighted avg       0.71      0.71      0.70       495
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.74       248
#            1       0.73      0.77      0.75       247
#
#     accuracy                           0.74       495
#    macro avg       0.74      0.74      0.74       495
# weighted avg       0.74      0.74      0.74       495
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.76       248
#            1       0.74      0.83      0.78       247
#
#     accuracy                           0.77       495
#    macro avg       0.78      0.77      0.77       495
# weighted avg       0.78      0.77      0.77       495
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66       248
#            1       0.66      0.63      0.64       247
#
#     accuracy                           0.65       495
#    macro avg       0.65      0.65      0.65       495
# weighted avg       0.65      0.65      0.65       495
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73       248
#            1       0.73      0.77      0.75       247
#
#     accuracy                           0.74       495
#    macro avg       0.74      0.74      0.74       495
# weighted avg       0.74      0.74      0.74       495
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.75       248
#            1       0.74      0.79      0.76       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       248
#            1       0.75      0.80      0.77       247
#
#     accuracy                           0.77       495
#    macro avg       0.77      0.77      0.77       495
# weighted avg       0.77      0.77      0.77       495
#
#
# 🎯 Parametric t-SNE output_dim=15, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67       248
#            1       0.67      0.64      0.65       247
#
#     accuracy                           0.66       495
#    macro avg       0.67      0.66      0.66       495
# weighted avg       0.67      0.66      0.66       495
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       248
#            1       0.70      0.73      0.71       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.74       248
#            1       0.73      0.79      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75       248
#            1       0.74      0.81      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.67       248
#            1       0.67      0.71      0.69       247
#
#     accuracy                           0.68       495
#    macro avg       0.68      0.68      0.68       495
# weighted avg       0.68      0.68      0.68       495
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73       248
#            1       0.72      0.77      0.75       247
#
#     accuracy                           0.74       495
#    macro avg       0.74      0.74      0.74       495
# weighted avg       0.74      0.74      0.74       495
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       248
#            1       0.73      0.78      0.75       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73       248
#            1       0.72      0.79      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.74       495
# weighted avg       0.75      0.75      0.74       495
#
#
# 🎯 Parametric t-SNE output_dim=16, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67       248
#            1       0.67      0.64      0.66       247
#
#     accuracy                           0.66       495
#    macro avg       0.66      0.66      0.66       495
# weighted avg       0.66      0.66      0.66       495
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.70       248
#            1       0.70      0.74      0.72       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       248
#            1       0.73      0.79      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75       248
#            1       0.73      0.81      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67       248
#            1       0.67      0.71      0.69       247
#
#     accuracy                           0.68       495
#    macro avg       0.68      0.68      0.68       495
# weighted avg       0.68      0.68      0.68       495
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70       248
#            1       0.69      0.77      0.73       247
#
#     accuracy                           0.72       495
#    macro avg       0.72      0.72      0.72       495
# weighted avg       0.72      0.72      0.72       495
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.75       248
#            1       0.74      0.79      0.76       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75       248
#            1       0.74      0.81      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.77      0.76      0.76       495
# weighted avg       0.77      0.76      0.76       495
#
#
# 🎯 Parametric t-SNE output_dim=18, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66       248
#            1       0.66      0.62      0.64       247
#
#     accuracy                           0.65       495
#    macro avg       0.65      0.65      0.65       495
# weighted avg       0.65      0.65      0.65       495
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       248
#            1       0.70      0.73      0.71       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       248
#            1       0.73      0.79      0.75       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76       248
#            1       0.74      0.82      0.78       247
#
#     accuracy                           0.77       495
#    macro avg       0.77      0.77      0.77       495
# weighted avg       0.77      0.77      0.77       495
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.66       248
#            1       0.66      0.74      0.70       247
#
#     accuracy                           0.68       495
#    macro avg       0.68      0.68      0.68       495
# weighted avg       0.68      0.68      0.68       495
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76       248
#            1       0.75      0.78      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       248
#            1       0.74      0.79      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74       248
#            1       0.73      0.82      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.75       495
# weighted avg       0.76      0.76      0.75       495
#
#
# 🎯 Parametric t-SNE output_dim=21, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66       248
#            1       0.66      0.62      0.64       247
#
#     accuracy                           0.65       495
#    macro avg       0.65      0.65      0.65       495
# weighted avg       0.65      0.65      0.65       495
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       248
#            1       0.70      0.74      0.72       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       248
#            1       0.73      0.77      0.75       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.75       248
#            1       0.74      0.83      0.78       247
#
#     accuracy                           0.77       495
#    macro avg       0.77      0.77      0.77       495
# weighted avg       0.77      0.77      0.77       495
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.72      0.66      0.69       248
#            1       0.69      0.75      0.72       247
#
#     accuracy                           0.70       495
#    macro avg       0.70      0.70      0.70       495
# weighted avg       0.70      0.70      0.70       495
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73       248
#            1       0.72      0.77      0.74       247
#
#     accuracy                           0.74       495
#    macro avg       0.74      0.74      0.74       495
# weighted avg       0.74      0.74      0.74       495
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75       248
#            1       0.74      0.82      0.78       247
#
#     accuracy                           0.77       495
#    macro avg       0.77      0.77      0.77       495
# weighted avg       0.77      0.77      0.77       495
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.74       248
#            1       0.73      0.80      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.76      0.75      0.75       495
# weighted avg       0.76      0.75      0.75       495
#
#
# 🎯 Parametric t-SNE output_dim=34, perplexity=10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66       248
#            1       0.66      0.62      0.64       247
#
#     accuracy                           0.65       495
#    macro avg       0.65      0.65      0.65       495
# weighted avg       0.65      0.65      0.65       495
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       248
#            1       0.70      0.73      0.71       247
#
#     accuracy                           0.71       495
#    macro avg       0.71      0.71      0.71       495
# weighted avg       0.71      0.71      0.71       495
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       248
#            1       0.73      0.79      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75       248
#            1       0.74      0.81      0.77       247
#
#     accuracy                           0.76       495
#    macro avg       0.76      0.76      0.76       495
# weighted avg       0.76      0.76      0.76       495
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.69      0.67      0.68       248
#            1       0.67      0.70      0.69       247
#
#     accuracy                           0.68       495
#    macro avg       0.68      0.68      0.68       495
# weighted avg       0.68      0.68      0.68       495
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73       248
#            1       0.72      0.78      0.75       247
#
#     accuracy                           0.74       495
#    macro avg       0.74      0.74      0.74       495
# weighted avg       0.74      0.74      0.74       495
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       248
#            1       0.73      0.79      0.76       247
#
#     accuracy                           0.75       495
#    macro avg       0.75      0.75      0.75       495
# weighted avg       0.75      0.75      0.75       495
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.81      0.72      0.76       248
#            1       0.75      0.83      0.79       247
#
#     accuracy                           0.78       495
#    macro avg       0.78      0.78      0.78       495
# weighted avg       0.78      0.78      0.78       495
#
#
# ✅ Hasil Hyperparameter Tuning Parametric t-SNE:
#  Output Dim  Perplexity               Model                                                  Best Params  Accuracy  Precision   Recall  F1-Score
#          14          10       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.771717   0.741007 0.834008  0.784762
#          14          10             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.767677   0.751908 0.797571  0.774067
#          14          10            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.757576   0.741445 0.789474  0.764706
#          14          10                 KNN                                           {'n_neighbors': 3}  0.743434   0.729008 0.773279  0.750491
#          14          10   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.741414   0.727969 0.769231  0.748031
#          14          10                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.705051   0.694981 0.728745  0.711462
#          14          10 Logistic Regression                                                  {'C': 0.01}  0.672727   0.676349 0.659919  0.668033
#          14          10            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.652525   0.658228 0.631579  0.644628
#          15          10       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.759596   0.735294 0.809717  0.770713
#          15          10                 KNN                                           {'n_neighbors': 3}  0.751515   0.731343 0.793522  0.761165
#          15          10             XGBoost {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200}  0.745455   0.724907 0.789474  0.755814
#          15          10            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.747475   0.732824 0.777328  0.754420
#          15          10   Gradient Boosting {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}  0.739394   0.723485 0.773279  0.747554
#          15          10                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.707071   0.696154 0.732794  0.714004
#          15          10            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}  0.682828   0.671756 0.712551  0.691552
#          15          10 Logistic Regression                                                  {'C': 0.01}  0.664646   0.673820 0.635628  0.654167
#          16          10             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.763636   0.742537 0.805668  0.772816
#          16          10       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.757576   0.734317 0.805668  0.768340
#          16          10            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.755556   0.738636 0.789474  0.763209
#          16          10                 KNN                                           {'n_neighbors': 3}  0.749495   0.732075 0.785425  0.757812
#          16          10   Gradient Boosting  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}  0.717172   0.694545 0.773279  0.731801
#          16          10                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.711111   0.696970 0.744939  0.720157
#          16          10            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 100}  0.678788   0.666667 0.712551  0.688845
#          16          10 Logistic Regression                                                    {'C': 10}  0.662626   0.668067 0.643725  0.655670
#          18          10       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.767677   0.742647 0.817814  0.778420
#          18          10             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.755556   0.726619 0.817814  0.769524
#          18          10   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.761616   0.750973 0.781377  0.765873
#          18          10            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.753535   0.735849 0.789474  0.761719
#          18          10                 KNN                                           {'n_neighbors': 3}  0.745455   0.726592 0.785425  0.754864
#          18          10                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.707071   0.696154 0.732794  0.714004
#          18          10            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 100}  0.680808   0.659498 0.744939  0.699620
#          18          10 Logistic Regression                                                  {'C': 0.01}  0.650505   0.658120 0.623482  0.640333
#          21          10       Random Forest                     {'max_depth': None, 'n_estimators': 200}  0.767677   0.737410 0.829960  0.780952
#          21          10            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.767677   0.740876 0.821862  0.779271
#          21          10             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}  0.753535   0.730627 0.801619  0.764479
#          21          10                 KNN                                           {'n_neighbors': 3}  0.745455   0.731801 0.773279  0.751969
#          21          10   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.735354   0.719697 0.769231  0.743640
#          21          10                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.709091   0.697318 0.736842  0.716535
#          21          10            AdaBoost                   {'learning_rate': 1.0, 'n_estimators': 50}  0.703030   0.685185 0.748988  0.715667
#          21          10 Logistic Regression                                                  {'C': 0.01}  0.650505   0.658120 0.623482  0.640333
#          34          10             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.775758   0.748175 0.829960  0.786948
#          34          10       Random Forest                     {'max_depth': None, 'n_estimators': 100}  0.761616   0.739777 0.805668  0.771318
#          34          10                 KNN                                           {'n_neighbors': 3}  0.749495   0.730337 0.789474  0.758755
#          34          10            CatBoost        {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.747475   0.727612 0.789474  0.757282
#          34          10   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.741414   0.724528 0.777328  0.750000
#          34          10                 SVM                                   {'C': 10, 'kernel': 'rbf'}  0.707071   0.696154 0.732794  0.714004
#          34          10            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 100}  0.680808   0.674510 0.696356  0.685259
#          34          10 Logistic Regression                                                  {'C': 0.01}  0.650505   0.659483 0.619433  0.638831

# %% [markdown]
# Copy to clipboard

# %%
out_dim = 34
df_filtered = df_results_tsne_tuned_sorted[df_results_tsne_tuned_sorted["Output Dim"] == out_dim]

# Drop kolom yang tidak perlu disalin
df_to_copy = df_filtered.drop(columns=["Output Dim", "Perplexity"])

# Tampilkan ke terminal
print(df_to_copy.to_string(index=False))

# Salin ke clipboard tanpa kolom tambahan
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
#               Model                                                 Best Params  Accuracy  Precision   Recall  F1-Score
#             XGBoost {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}  0.775758   0.748175 0.829960  0.786948
#       Random Forest                    {'max_depth': None, 'n_estimators': 100}  0.761616   0.739777 0.805668  0.771318
#                 KNN                                          {'n_neighbors': 3}  0.749495   0.730337 0.789474  0.758755
#            CatBoost       {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}  0.747475   0.727612 0.789474  0.757282
#   Gradient Boosting {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}  0.741414   0.724528 0.777328  0.750000
#                 SVM                                  {'C': 10, 'kernel': 'rbf'}  0.707071   0.696154 0.732794  0.714004
#            AdaBoost                 {'learning_rate': 1.0, 'n_estimators': 100}  0.680808   0.674510 0.696356  0.685259
# Logistic Regression                                                 {'C': 0.01}  0.650505   0.659483 0.619433  0.638831

# %% [markdown]
# Export to CSV

# %%
# (opsional) simpan ke file CSV
df_results_tsne_tuned.to_csv(f"{lowercase_dataset}_tsne.csv", index=False)

# %% [markdown]
# ##### Cross Validation for Random Forest after PCA (best model)
